# %% [markdown]
# <a href="https://colab.research.google.com/github/ShardenduMishra22/Data-Science/blob/main/NumPy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Learning NumPy

# %%
import numpy as np

# Creating a 1-dimensional array
arr1 = np.array([1, 2, 3])
print("1D array arr1:\n", arr1)
print("\n")

# Creating a 2-dimensional array (matrix)
arr2 = np.array([[1, 2, 3], [4, 5, 6]])
print("2D array arr2:\n", arr2)
print("\n")

# Attributes of arrays
shape_arr1 = arr1.shape
shape_arr2 = arr2.shape
ndim_arr1 = arr1.ndim
size_arr1 = arr1.size
type_arr1 = arr1.dtype

print("Shape of arr1:", shape_arr1)
print("Shape of arr2:", shape_arr2)
# Out:
# 1D array arr1:
#  [1 2 3]
#
#
# 2D array arr2:
#  [[1 2 3]
#  [4 5 6]]
#
#
# Shape of arr1: (3,)
# Shape of arr2: (2, 3)

# %%
print("Data type of arr1:", type_arr1)
print("Total elements in arr1:", size_arr1)
print("Number of dimensions of arr1:", ndim_arr1)

print("\n")
# Out:
# Data type of arr1: int64
# Total elements in arr1: 3
# Number of dimensions of arr1: 1

# %%
# arr1
# [1, 2, 3]

# arr2
# [
#  [1, 2, 3],
#  [4, 5, 6],
# ]

# Basic operations
sum_arr1 = arr1.sum()
mean_arr1 = arr1.mean()

print("Sum of arr1:", sum_arr1)
print("Mean of arr1:", mean_arr1)
# Out:
# Sum of arr1: 6
# Mean of arr1: 2.0

# %%
# Element-wise operations
arr1_plus_2 = arr1 + 2
arr2_times_3 = arr2 * 3

print("arr1 + 2:", arr1_plus_2)
print("arr2 * 3:", arr2_times_3)
# Out:
# arr1 + 2: [3 4 5]
# arr2 * 3: [[ 3  6  9]
#  [12 15 18]]

# %%
import numpy as np

# Creating a 1-dimensional array
arr1 = np.array([1, 2, 3])
print("1D array arr1:\n", arr1, "\n")

# Creating a 2-dimensional array (matrix)
arr2 = np.array([[1, 2, 3], [4, 5, 6]])
print("2D array arr2:\n", arr2)
# Out:
# 1D array arr1:
#  [1 2 3]
#
# 2D array arr2:
#  [[1 2 3]
#  [4 5 6]]

# %%
# Attributes of arrays
print("Shape of arr1:", arr1.shape)
print("Shape of arr2:", arr2.shape)
print("Number of dimensions of arr1:", arr1.ndim)
print("Size of arr1:", arr1.size)
print("Data type of arr1:", arr1.dtype)
# Out:
# Shape of arr1: (3,)
# Shape of arr2: (2, 3)
# Number of dimensions of arr1: 1
# Size of arr1: 3
# Data type of arr1: int64

# %%
# Indexing and slicing
first_element = arr1[0]
last_element = arr2[1, 2]
slice_arr1 = arr1[1:]
slice_arr2 = arr2[:, 1:3]

print("First element of arr1:", first_element)
print("Last element of arr2:", last_element)
print("Slice of arr1 from index 1:", slice_arr1)
print("Slice of arr2, all rows columns 1 and 2:\n", slice_arr2)
# Out:
# First element of arr1: 1
# Last element of arr2: 6
# Slice of arr1 from index 1: [2 3]
# Slice of arr2, all rows columns 1 and 2:
#  [[2 3]
#  [5 6]]

# %%
# arr1
# [1, 2, 3]

# arr2
# [
#  [1, 2, 3],
#  [4, 5, 6],
# ]

# Boolean indexing
bool_index = arr1 > 1
filtered_arr1 = arr1[arr1 > 1]

print("Boolean index (arr1 > 1):", bool_index)
print("Filtered arr1 elements > 1:", filtered_arr1, "\n")

# Reshaping arrays
reshaped_arr2 = arr2.reshape(3, 2)
print("arr2 reshaped to 3x2:\n", reshaped_arr2, "\n")

# Combining arrays
combined_arr = np.concatenate([arr1, arr1])
print("arr1 concatenated with itself:", combined_arr)
# Out:
# Boolean index (arr1 > 1): [False  True  True]
# Filtered arr1 elements > 1: [2 3]
#
# arr2 reshaped to 3x2:
#  [[1 2]
#  [3 4]
#  [5 6]]
#
# arr1 concatenated with itself: [1 2 3 1 2 3]

# %%
# Mathematical functions
sqrt_arr1 = np.sqrt(arr1)          # Square root element-wise: [1.0, 1.414, 1.732]
log_arr1 = np.log(arr1)            # Natural logarithm element-wise: [0.0, 0.693, 1.099]

# Statistical methods
max_arr2 = arr2.max()              # Maximum element in arr2: 6
min_arr2 = arr2.min()              # Minimum element in arr2: 1
mean_arr2 = arr2.mean(axis=0)      # Mean of columns: [2.5, 3.5, 4.5]
sum_arr2_axis1 = arr2.sum(axis=1)  # Sum of rows: [6, 15]

# Broadcasting
arr3 = np.array([1, 0, 1])         # Array for broadcasting
broadcast_sum = arr2 + arr3        # Adds arr3 to each row of arr2:
# [[2, 2, 4],
#  [5, 5, 7]]

# %%
import numpy as np
import imageio.v2 as imageio
import matplotlib.pyplot as plt

try:
    image = imageio.imread('image.png')

    plt.figure(figsize=(10, 5))
    plt.title("Original Image")
    plt.imshow(image)
    plt.subplot(121)
    plt.axis("off")

    plt.figure(figsize=(10, 5))
    plt.title("Inverted Image")
    plt.imshow(1 - image)
    plt.subplot(121)
    plt.axis("off")

    plt.show()
except:
    print("image.png file not found")
